# %%
type of headers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# request headers:
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
